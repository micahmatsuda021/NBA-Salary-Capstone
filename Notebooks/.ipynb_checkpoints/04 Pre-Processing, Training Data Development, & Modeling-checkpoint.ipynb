# %% [markdown]
# # 04 Pre-Processing and Training Data Development

# %% [markdown]
# ## Goals

# %% [markdown]
#  - Create dummy or indicator features for categorical variables<br>
#  - Standardize the magnitude of numeric features using a scaler<br>
#  - Split your data into testing and training datasets

# %%
# %reset_selective -f regex
import os
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import pprint
import numpy as np
import seaborn as sns
from scipy.stats import zscore
from sklearn import preprocessing
# %matplotlib inline

# %%
df=pd.read_csv('players_cleaned_final.csv')
del[df['Unnamed: 0']]
df.columns
# Out:
# Index(['Player', 'Stats_Year', 'Ht', 'Wt', 'Colleges', 'Pos', 'Age', 'Tm',
#        'Team', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P',
#        '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST',
#        'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Pts Won', 'Pts Max', 'Share', 'W',
#        'L', 'W/L%', 'GB', 'PS/G', 'PA/G', 'SRS', 'Contract', 'rank',
#        'Contract_Year', 'Contract_Team', 'Salary', 'Salary Cap',
#        'Adjusted Salary 2022'],
#       dtype='object')

# %% [markdown]
# dummy variables

# %%
# Creating dummy variables for Position first
positions = pd.get_dummies(df['Pos'])
df = pd.concat([df, positions], axis=1)

# Creating dummy variables for Contract_Team
con_team = pd.get_dummies(df['Contract_Team'])
df = pd.concat([df, con_team], axis=1)

# %%
df.columns
# Out:
# Index(['Player', 'Stats_Year', 'Ht', 'Wt', 'Colleges', 'Pos', 'Age', 'Tm',
#        'Team', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P',
#        '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST',
#        'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Pts Won', 'Pts Max', 'Share', 'W',
#        'L', 'W/L%', 'GB', 'PS/G', 'PA/G', 'SRS', 'Contract', 'rank',
#        'Contract_Year', 'Contract_Team', 'Salary', 'Salary Cap',
#        'Adjusted Salary 2022', 'C', 'PF', 'PF-C', 'PG', 'PG-SG', 'SF', 'SF-PF',
#        'SG', 'SG-PG', 'SG-SF', 'Atlanta Hawks', 'Boston Celtics',
#        'Brooklyn Nets', 'Charlotte Bobcats', 'Charlotte Hornets',
#        'Chicago Bulls', 'Cleveland Cavaliers', 'Dallas Mavericks',
#        'Denver Nuggets', 'Detroit Pistons', 'Golden State Warriors',
#        'Houston Rockets', 'Indiana Pacers', 'Los Angeles Clippers',
#        'Los Angeles Lakers', 'Memphis Grizzlies', 'Miami Heat',
#        'Milwaukee Bucks', 'Minnesota Timberwolves', 'New Jersey Nets',
#        'New Orleans Hornets', 'New Orleans Pelicans',
#        'New Orleans/Oklahoma City Hornets', 'New York Knicks',
#        'Oklahoma City Thunder', 'Orlando Magic', 'Philadelphia 76ers',
#        'Phoenix Suns', 'Portland Trail Blazers', 'Sacramento Kings',
#        'San Antonio Spurs', 'Seattle SuperSonics', 'Toronto Raptors',
#        'Utah Jazz', 'Vancouver Grizzlies', 'Washington Bullets',
#        'Washington Wizards'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1236 entries, 0 to 1235
# Data columns (total 98 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Player                             1236 non-null   object
#  1   Stats_Year                         1236 non-null   int64
#  2   Ht                                 1236 non-null   object
#  3   Wt                                 1236 non-null   float64
#  4   Colleges                           1236 non-null   object
#  5   Pos                                1236 non-null   object
#  6   Age                                1236 non-null   int64
#  7   Tm                                 1236 non-null   object
#  8   Team                               1236 non-null   object
#  9   G                                  1236 non-null   int64
#  10  GS                                 1236 non-null   int64
#  11  MP                                 1236 non-null   float64
#  12  FG                                 1236 non-null   float64
#  13  FGA                                1236 non-null   float64
#  14  FG%                                1236 non-null   float64
#  15  3P                                 1236 non-null   float64
#  16  3PA                                1236 non-null   float64
#  17  3P%                                1236 non-null   float64
#  18  2P                                 1236 non-null   float64
#  19  2PA                                1236 non-null   float64
#  20  2P%                                1236 non-null   float64
#  21  eFG%                               1236 non-null   float64
#  22  FT                                 1236 non-null   float64
#  23  FTA                                1236 non-null   float64
#  24  FT%                                1236 non-null   float64
#  25  ORB                                1236 non-null   float64
#  26  DRB                                1236 non-null   float64
#  27  TRB                                1236 non-null   float64
#  28  AST                                1236 non-null   float64
#  29  STL                                1236 non-null   float64
#  30  BLK                                1236 non-null   float64
#  31  TOV                                1236 non-null   float64
#  32  PF                                 1236 non-null   float64
#  33  PTS                                1236 non-null   float64
#  34  Pts Won                            1236 non-null   float64
#  35  Pts Max                            1236 non-null   float64
#  36  Share                              1236 non-null   float64
#  37  W                                  1236 non-null   int64
#  38  L                                  1236 non-null   int64
#  39  W/L%                               1236 non-null   float64
#  40  GB                                 1236 non-null   float64
#  41  PS/G                               1236 non-null   float64
#  42  PA/G                               1236 non-null   float64
#  43  SRS                                1236 non-null   float64
#  44  Contract                           1236 non-null   int64
#  45  rank                               1236 non-null   int64
#  46  Contract_Year                      1236 non-null   float64
#  47  Contract_Team                      1236 non-null   object
#  48  Salary                             1236 non-null   float64
#  49  Salary Cap                         1236 non-null   float64
#  50  Adjusted Salary 2022               1236 non-null   float64
#  51  C                                  1236 non-null   uint8
#  52  PF                                 1236 non-null   uint8
#  53  PF-C                               1236 non-null   uint8
#  54  PG                                 1236 non-null   uint8
#  55  PG-SG                              1236 non-null   uint8
#  56  SF                                 1236 non-null   uint8
#  57  SF-PF                              1236 non-null   uint8
#  58  SG                                 1236 non-null   uint8
#  59  SG-PG                              1236 non-null   uint8
#  60  SG-SF                              1236 non-null   uint8
#  61  Atlanta Hawks                      1236 non-null   uint8
#  62  Boston Celtics                     1236 non-null   uint8
#  63  Brooklyn Nets                      1236 non-null   uint8
#  64  Charlotte Bobcats                  1236 non-null   uint8
#  65  Charlotte Hornets                  1236 non-null   uint8
#  66  Chicago Bulls                      1236 non-null   uint8
#  67  Cleveland Cavaliers                1236 non-null   uint8
#  68  Dallas Mavericks                   1236 non-null   uint8
#  69  Denver Nuggets                     1236 non-null   uint8
#  70  Detroit Pistons                    1236 non-null   uint8
#  71  Golden State Warriors              1236 non-null   uint8
#  72  Houston Rockets                    1236 non-null   uint8
#  73  Indiana Pacers                     1236 non-null   uint8
#  74  Los Angeles Clippers               1236 non-null   uint8
#  75  Los Angeles Lakers                 1236 non-null   uint8
#  76  Memphis Grizzlies                  1236 non-null   uint8
#  77  Miami Heat                         1236 non-null   uint8
#  78  Milwaukee Bucks                    1236 non-null   uint8
#  79  Minnesota Timberwolves             1236 non-null   uint8
#  80  New Jersey Nets                    1236 non-null   uint8
#  81  New Orleans Hornets                1236 non-null   uint8
#  82  New Orleans Pelicans               1236 non-null   uint8
#  83  New Orleans/Oklahoma City Hornets  1236 non-null   uint8
#  84  New York Knicks                    1236 non-null   uint8
#  85  Oklahoma City Thunder              1236 non-null   uint8
#  86  Orlando Magic                      1236 non-null   uint8
#  87  Philadelphia 76ers                 1236 non-null   uint8
#  88  Phoenix Suns                       1236 non-null   uint8
#  89  Portland Trail Blazers             1236 non-null   uint8
#  90  Sacramento Kings                   1236 non-null   uint8
#  91  San Antonio Spurs                  1236 non-null   uint8
#  92  Seattle SuperSonics                1236 non-null   uint8
#  93  Toronto Raptors                    1236 non-null   uint8
#  94  Utah Jazz                          1236 non-null   uint8
#  95  Vancouver Grizzlies                1236 non-null   uint8
#  96  Washington Bullets                 1236 non-null   uint8
#  97  Washington Wizards                 1236 non-null   uint8
# dtypes: float64(36), int64(8), object(7), uint8(47)
# memory usage: 549.3+ KB

# %%
df.shape
# Out:
# (1236, 98)

# %%
X = df.drop(['Pos','Adjusted Salary 2022','Player', 'Ht', 'Colleges', 'Tm', 'Team', 'Contract_Team', 'Contract', 'rank', 'Contract_Year', 'Salary', 'Salary Cap'], axis=1)
y = df['Adjusted Salary 2022']

# %%
X.columns
# Out:
# Index(['Stats_Year', 'Wt', 'Age', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P',
#        '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB',
#        'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Pts Won',
#        'Pts Max', 'Share', 'W', 'L', 'W/L%', 'GB', 'PS/G', 'PA/G', 'SRS', 'C',
#        'PF', 'PF-C', 'PG', 'PG-SG', 'SF', 'SF-PF', 'SG', 'SG-PG', 'SG-SF',
#        'Atlanta Hawks', 'Boston Celtics', 'Brooklyn Nets', 'Charlotte Bobcats',
#        'Charlotte Hornets', 'Chicago Bulls', 'Cleveland Cavaliers',
#        'Dallas Mavericks', 'Denver Nuggets', 'Detroit Pistons',
#        'Golden State Warriors', 'Houston Rockets', 'Indiana Pacers',
#        'Los Angeles Clippers', 'Los Angeles Lakers', 'Memphis Grizzlies',
#        'Miami Heat', 'Milwaukee Bucks', 'Minnesota Timberwolves',
#        'New Jersey Nets', 'New Orleans Hornets', 'New Orleans Pelicans',
#        'New Orleans/Oklahoma City Hornets', 'New York Knicks',
#        'Oklahoma City Thunder', 'Orlando Magic', 'Philadelphia 76ers',
#        'Phoenix Suns', 'Portland Trail Blazers', 'Sacramento Kings',
#        'San Antonio Spurs', 'Seattle SuperSonics', 'Toronto Raptors',
#        'Utah Jazz', 'Vancouver Grizzlies', 'Washington Bullets',
#        'Washington Wizards'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %% [markdown]
# # 05 Modeling

# %% [markdown]
# The goal of the modeling step is to develop a final model that effectively predicts a NBA player's salary. After looking at the types of models that would be appropriate given the modeling response and the features in the dataset, I will build two to three models.

# %%
import statsmodels.api as sm
from numpy import mean
from numpy import std
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler,PolynomialFeatures
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.model_selection import KFold
from sklearn.model_selection import RepeatedKFold
from sklearn import metrics
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet 
from sklearn.linear_model import LassoCV, RidgeCV, ElasticNetCV
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.inspection import permutation_importance
import shap
from sklearn import preprocessing

# %%
X_train
# Out:
#       Stats_Year     Wt  Age   G  GS    MP   FG   FGA    FG%   3P  ...  \
# 326         2000  220.0   22  49   1   7.0  1.1   2.9  0.389  0.3  ...
# 509         2017  209.0   22  35   1   7.1  0.7   2.5  0.292  0.4  ...
# 1224        2011  220.0   19  38  16  13.9  1.7   4.2  0.406  0.1  ...
# 1205        2000  185.0   23  75  11  23.9  3.5   8.7  0.405  0.7  ...
# 59          2016  210.0   23  29  11  20.7  1.3   4.3  0.310  0.7  ...
# ...          ...    ...  ...  ..  ..   ...  ...   ...    ...  ...  ...
# 715         2012  215.0   21  66  29  24.4  4.8  10.9  0.443  1.7  ...
# 905         1996  220.0   31  81  80  30.1  5.3  10.1  0.527  0.0  ...
# 1096        2006  215.0   23  22   0   8.0  1.0   2.5  0.389  0.1  ...
# 235         1996  180.0   34  79   8  22.3  3.2   7.5  0.428  1.0  ...
# 1061        2015  223.0   22  38  13  22.8  5.1  10.4  0.489  0.5  ...
#
#       Phoenix Suns  Portland Trail Blazers  Sacramento Kings  \
# 326              0                       0                 0
# 509              0                       1                 0
# 1224             0                       0                 0
# 1205             0                       0                 0
# 59               0                       0                 0
# ...            ...                     ...               ...
# 715              0                       0                 0
# 905              0                       0                 1
# 1096             0                       1                 0
# 235              0                       0                 0
# 1061             0                       0                 0
#
#       San Antonio Spurs  Seattle SuperSonics  Toronto Raptors  Utah Jazz  \
# 326                   0                    0                0          0
# 509                   0                    0                0          0
# 1224                  0                    0                0          0
# 1205                  0                    0                0          0
# 59                    0                    0                0          0
# ...                 ...                  ...              ...        ...
# 715                   0                    0                0          0
# 905                   0                    0                0          0
# 1096                  0                    0                0          0
# 235                   0                    1                0          0
# 1061                  0                    0                0          0
#
#       Vancouver Grizzlies  Washington Bullets  Washington Wizards
# 326                     0                   0                   0
# 509                     0                   0                   0
# 1224                    0                   0                   0
# 1205                    0                   0                   0
# 59                      0                   0                   0
# ...                   ...                 ...                 ...
# 715                     0                   0                   0
# 905                     0                   0                   0
# 1096                    0                   0                   0
# 235                     0                   0                   0
# 1061                    0                   0                   0
#
# [865 rows x 85 columns]

# %%
# making dummy model 
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error
y_pred = np.ones(len(y_test))*y_train.mean()
print(mean_absolute_percentage_error(y_test, y_pred))
print(mean_squared_error(y_test,y_pred, squared=False))
# Out:
# 3.046949970816524
# 11369831.43931254

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge

params = {'alpha': [.1, 1, 10]}
gs = GridSearchCV(Ridge(), param_grid = params, scoring='neg_mean_absolute_error').fit(X_train, y_train)
print(gs.best_estimator_)
print(gs.best_score_)
# Out:
# Ridge(alpha=10)
# -3461968.0903638275

# %%
ridge = Ridge(alpha = 10)
ridge.fit(X_train, y_train)
y_pred = ridge.predict(X_test)
print(mean_absolute_percentage_error(y_test, y_pred))
print(mean_squared_error(y_test,y_pred, squared=False))
# Out:
# 1.7206571629418244
# 7147890.970616082

# %%
from sklearn.ensemble import RandomForestRegressor
#OTHER PARAMETERS: max_features, max_depth

params = {'n_estimators': [10, 50, 200]}
gs = GridSearchCV(RandomForestRegressor(), param_grid = params, scoring = 'neg_mean_absolute_percentage_error').fit(X_train, y_train)
print(gs.best_estimator_)
print(gs.best_score_)
# Out:
# RandomForestRegressor(n_estimators=200)
# -1.3205734048360243

# %%
rf = RandomForestRegressor(n_estimators = 200)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
print(mean_absolute_percentage_error(y_test, y_pred))
print(mean_squared_error(y_test,y_pred, squared=False))
# Out:
# 1.7441946494769882
# 8476479.877478095
